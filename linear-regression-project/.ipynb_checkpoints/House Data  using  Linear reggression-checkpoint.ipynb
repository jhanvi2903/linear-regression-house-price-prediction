# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # To read the dataset using pandas

# %%
Raw_Housing_data=pd.read_csv("House_data.csv")

# %% [markdown]
# # To view the dataset

# %%
Raw_Housing_data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
Raw_Housing_data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
Raw_Housing_data.head(10)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
# 5  7237550310         14 May 2017   1230000.0               4
# 6  1321400060        14 June 2017    257500.0               3
# 7  2008000270     15 January 2016    291850.0               3
# 8  2414600126       15 April 2016    229500.0               3
# 9  3793500160       15 March 2016    323000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# ...

# %%
Raw_Housing_data.tail()
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 21608             2.50               1530.0              1131.0           3.0
# 21609             2.50               2310.0              5813.0           2.0
# 21610             0.75               1020.0              1350.0           2.0
# 21611             2.50               1600.0              2388.0           2.0
# 21612             0.75               1020.0              1076.0           2.0
#
#       Waterfront View No of Times Visited  ... Overall Grade  \
# ...

# %%
Raw_Housing_data.tail(10)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 21603  7852140040      14 August 2017    507250.0               3
# 21604  9834201367     15 January 2016    429000.0               3
# 21605  3448900210     14 October 2017    610685.0               4
# 21606  7936000429       15 March 2016   1010000.0               4
# 21607  2997800021    15 February 2016    475000.0               3
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 21603             2.50               2270.0              5536.0           2.0
# 21604             2.00               1490.0              1126.0           3.0
# ...

# %% [markdown]
# # Descriptive Statistics of the dataset

# %%
Raw_Housing_data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %% [markdown]
# # Detail information about variable

# %%
Raw_Housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %% [markdown]
# # Descriptive statistics of Sale Price variable describing mean, standard deviation, minimum value, maximum value

# %%
Raw_Housing_data['Sale Price'].mean()
# Out:
# 540198.4357443658

# %%
Raw_Housing_data['Sale Price'].std()
# Out:
# 367388.99446065375

# %%
Raw_Housing_data['Sale Price'].min()
# Out:
# 75000.0

# %%
Raw_Housing_data['Sale Price'].max()
# Out:
# 7700000.0

# %% [markdown]
# # First, Second & Third Quantile values of Sale Price

# %%
Raw_Housing_data['Sale Price'].quantile(.25)
# Out:
# 321950.0

# %%
Raw_Housing_data['Sale Price'].quantile(.50)
# Out:
# 450000.0

# %%
Raw_Housing_data['Sale Price'].quantile(.75)
# Out:
# 645000.0

# %% [markdown]
# # Line Graph of Sale Price

# %%
plt.plot(Raw_Housing_data['Sale Price'], marker='o',markerfacecolor='blue', markersize=5,color= 'green', linewidth=5 ,linestyle='dashed')
plt.xlabel("Record Number")
plt.ylabel("Sale Price")
plt.title("Line Graph of Sale Price")
plt.show()

# %% [markdown]
# # Pie chart of Condition of the House

# %%
Raw_Housing_data.groupby('Condition of the House')['ID'].count()
# Out:
# Condition of the House
# Bad             30
# Excellent     1701
# Fair         14031
# Good          5679
# Okay           172
# Name: ID, dtype: int64

# %%
values=(30,1701,14031,5679,172)
labels=('Bad','Excellent','Fair','Good','Okay')
plt.pie(values,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c0b8bdbb88>,
# ...
#  [Text(1.099989541385049, 0.004796753434368107, 'Bad'),
#   Text(1.0641591373844368, 0.27850553014475643, 'Excellent'),
#   Text(-0.9085709380486652, 0.620079713047741, 'Fair'),
#   Text(0.7046888223897579, -0.8446381850229934, 'Good'),
#   Text(1.0996562341282203, -0.02749848619362501, 'Okay')])

# %% [markdown]
# # Bar Graph of Condition of the House

# %%
plt.bar(labels, values, color='grey', linewidth=5, linestyle='dashed')
plt.xlabel("Condition of the House")
plt.ylabel("Count of the House")
plt.title("Bar Graph of Condition of the House")
plt.show()

# %% [markdown]
# # Scatter Plot for visualizing the varation of  Sale Price with Flat Area(in Sqft)

# %%
plt.scatter(x=Raw_Housing_data['Flat Area (in Sqft)'], y=Raw_Housing_data['Sale Price'], color='violet')
plt.xlabel('Area')
plt.ylabel('Sale Price')
plt.title('Varation of Sale Price with Area')
plt.show()

# %% [markdown]
# # Scatter Plot for visualizing the varation of Sale Price with No of Bathrooms

# %%
plt.scatter(x=Raw_Housing_data['No of Bathrooms'], y=Raw_Housing_data['Sale Price'], color='skyblue')
plt.xlabel('No of Bathrooms')
plt.ylabel('Sale Price')
plt.title('Varation of Sale Price with No of Bathrooms')
plt.show()

# %% [markdown]
# # Scatter Plot for visualizing the varation of Sale Price with the Age of House (in Years)

# %%
plt.scatter(x=Raw_Housing_data['Age of House (in Years)'], y=Raw_Housing_data['Sale Price'], color='yellow')
plt.xlabel('Age of House (in Years)')
plt.ylabel('Sale Price')
plt.title('Variation of Sale Price with Age of House (in years)')
plt.show()

# %% [markdown]
# # Univariate Analysis - The process of analyzing or studying one variable in detail

# %% [markdown]
# Univariate Analysis of the target variable - Sale Price

# %% [markdown]
# 1. Descriptive Statistics of Sale Price

# %%
Raw_Housing_data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.401984e+05
# std      3.673890e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %% [markdown]
# # Outlier

# %% [markdown]
# Outlier is a data point that is distant from another data point.It's value lies outside the usual range of rest of the values in the data

# %%
plt.scatter(x=Raw_Housing_data['ID'],y=Raw_Housing_data['Sale Price'])

# %% [markdown]
# # Creation of Box & Whisker Plot

# %% [markdown]
# We will not use the matplot library as it doesn't have capacity to ignore the missing values of variable

# %% [markdown]
# We will use the Seaborn library as it has the capacity to ignore the missing values of variable and creates the box plot easily

# %%
import seaborn as sns

# %%
sns.boxplot(x=Raw_Housing_data['Sale Price'], color='yellow')

# %% [markdown]
# # Occurence of an Outlier due to:-

# %% [markdown]
# 1.Genuine Varability in the data
#
# 2.Due to recording error

# %% [markdown]
# # Outlier cause problem in analysis & modeling

# %% [markdown]
# # Different ways of treating Outliers :-

# %% [markdown]
# 1. Deletion
#
# 2. Capping or Imputing
#
# 3. Data transformation
#
# 4. Binning

# %%
q1=Raw_Housing_data['Sale Price'].quantile(.25)
q2=Raw_Housing_data['Sale Price'].quantile(.50)
q3=Raw_Housing_data['Sale Price'].quantile(.75)

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 323050.0

# %%
upper_limit=q3 + 1.5 * iqr
lower_limit=q1 - 1.5 * iqr
upper_limit, lower_limit
# Out:
# (1129575.0, -162625.0)

# %% [markdown]
# Function to replace outliers with limit values

# %%
def limit_imputer(value):
    if value > upper_limit:
        return upper_limit
    if value < lower_limit:
        return lower_limit
    else:
        return value

# %%
Raw_Housing_data['Sale Price']=Raw_Housing_data['Sale Price'].apply(limit_imputer)

# %%
Raw_Housing_data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64

# %% [markdown]
# Outliers are treated.

# %% [markdown]
# # Treating the missing values in Sale Price

# %%
Raw_Housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %% [markdown]
# Tota entries are 21613 and there are 4 missing values in Sale Price i.e there are 21609 entries

# %% [markdown]
# We can treat the missing values using deletion or imputation
#
# Deletion is preferred over imputation as data will get modified in imputation i.e it will not remain original, so Deletion method is better to remove those rows containing missing values

# %% [markdown]
# # Treating the missing values in Sale Price using Deletion Method

# %%
Raw_Housing_data.dropna(inplace= True, axis=0, subset= ['Sale Price'])

# %% [markdown]
# Here, dropna is function which is used in
#
# inplace=True means data is modified in original data
#
# axis=0 means row wise deletion will take place
#
# subset=['Sale Price'] means deletion is done according to Sale Price containing missing values

# %% [markdown]
# Using dropna function missing values rows with respect to Sale Price are deleted

# %%
Raw_Housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
plt.hist(Raw_Housing_data['Sale Price'], bins=10, color='Violet')
plt.xlabel("Intervals")
plt.ylabel("Sale Price")
plt.title("Histogram of selling price")
plt.show()

# %% [markdown]
# # Treating the missing values in independent variable using imputation method

# %%
Numerical_columns=['No of Bathrooms','Flat Area (in Sqft)', 'Lot Area after Renovation (in Sqft)','Area of the House from Basement (in Sqft)',
                   'Latitude','Longitude','Living Area after Renovation (in Sqft)']

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan, strategy='median')
Raw_Housing_data[Numerical_columns]=imputer.fit_transform(Raw_Housing_data[Numerical_columns])

# %%
Raw_Housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %% [markdown]
# We can see that all the independent variable contains equal number of entries.

# %% [markdown]
# But the Zipcode still contains 1 less entry i.e 21608

# %%
Raw_Housing_data['Zipcode'].shape
# Out:
# (21609,)

# %% [markdown]
# It shows that it is single dimensional array as there is no number mentioned after 21609, so we will reshape it.

# %%
column= Raw_Housing_data['Zipcode'].values.reshape(-1,1)
column.shape
# Out:
# (21609, 1)

# %%
column= Raw_Housing_data['Zipcode'].values.reshape(-1,1)
imputer=SimpleImputer(missing_values=np.nan, strategy='most_frequent')
Raw_Housing_data['Zipcode']=imputer.fit_transform(column)

# %%
Raw_Housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %% [markdown]
# # Transformation of variable

# %% [markdown]
# As it does not make any sense of varation of Sale Price w.r.t Zipcode, so we will change the datatype of Zipcode from Numeric to Categorical variable

# %%
Raw_Housing_data['Zipcode']=Raw_Housing_data['Zipcode'].astype(object)

# %%
Raw_Housing_data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                       object
# Latitude                                     float64
# ...

# %% [markdown]
# We can see that transformation has take place from float to object in case of Zipcode

# %%
Raw_Housing_data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %% [markdown]
# As we can see,'No of Times Visited' variable which is categorical and it does not make sense when plotting the graph i.e variation of 'Sale Price' w.r.t 'No of Times Visited'
#
# So we will map the categorical datatype of variable ' No of Times Visited' with the numeric data using dictonary

# %%
Raw_Housing_data['No of Times Visited'].unique()
# Out:
# array(['None', 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
Mapping={ 'None':0,
          'Once':1,
          'Twice':2,
          'Thrice':3,
          'Four':4
         }
Raw_Housing_data['No of Times Visited']=Raw_Housing_data['No of Times Visited'].map(Mapping)

# %%
Raw_Housing_data['No of Times Visited'].unique()
# Out:
# array([0, 3, 4, 2, 1], dtype=int64)

# %% [markdown]
# # Derivation of 2 varaibles from the Renovated Year

# %% [markdown]
# 1. Ever Renovate
#
# 2. Years Since Renovation

# %%
Raw_Housing_data=pd.read_csv("Transformed_house_data1.csv")

# %%
Raw_Housing_data['Ever Renovated']=np.where(Raw_Housing_data['Renovated Year']==0 , 'No','Yes')

# %%
Raw_Housing_data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ...  \
# 0              No                None  ...
# 1              No                None  ...
# ...

# %%
Raw_Housing_data['Purchase Year']=pd.DatetimeIndex(Raw_Housing_data['Date House was Sold']).year

# %%
Raw_Housing_data['Years Since Renovation']=np.where(Raw_Housing_data['Ever Renovated']=='Yes', 
                                            abs(Raw_Housing_data['Purchase Year']- Raw_Housing_data['Renovated Year']),0)

# %%
Raw_Housing_data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Age of House (in Years)  \
# 0              No                None  ...                      63
# ...

# %% [markdown]
# We have derived the Purchase Year from Date House was Sold and derived Years Since Renovation from Renovated Year and Purchase Year so we will drop the 3 variables to make our code tidy.Those 3 variables which we will drop are:-
#
# 1.Date House was Sold
#
# 2.Renovated Year
#
# 3.Purchase Year

# %%
Raw_Housing_data.drop(columns=['Date House was Sold','Renovated Year','Purchase Year'],inplace=True)

# %%
Raw_Housing_data.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited Condition of the House  ...  \
# 0                None                   Fair  ...
# 1                None                   Fair  ...
# ...

# %% [markdown]
# # Building First Predictive Model with Mean Regression

# %% [markdown]
# Simplest Prediction Model :- It predicts the same Sale Price for every house

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.simplefilter('ignore')
plt.style.use('dark_background')
from sklearn.metrics import mean_squared_error as mse

# %%
data=pd.read_csv('Transformed_Housing_Data2.csv')
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
data['mean_sales']=data['Sale_Price'].mean()
data['mean_sales'].head()
# Out:
# 0    511618.558147
# 1    511618.558147
# 2    511618.558147
# 3    511618.558147
# 4    511618.558147
# Name: mean_sales, dtype: float64

# %%
plt.figure(dpi=100)
k=range(0,len(data))
plt.scatter(k,data['Sale_Price'].sort_values(),color='red',label='Actual Sale Price')
plt.plot(k,data['mean_sales'].sort_values(),color='green',label='mean-price')
plt.xlabel('Fitted points(Ascending)')
plt.ylabel('Sale Price')
plt.title('Overall Mean')
plt.legend()

# %% [markdown]
# Here the straight line shows that the mean_sale is not the good predicor for very high priced and for very low priced house.

# %% [markdown]
# # Improving upon the mean prediction model

# %% [markdown]
# Average Sale Price w.r.t the overall grade

# %%
grades_mean=data.pivot_table(values='Sale_Price',columns='Overall Grade',aggfunc=np.mean)
grades_mean
# Out:
# Overall Grade        1          2              3              4   \
# Sale_Price     142000.0  1129575.0  205666.666667  214381.034483
#
# Overall Grade             5             6              7              8   \
# Sale_Price     248523.971074  301882.01472  402239.619779  537584.082097
#
# Overall Grade             9              10
# Sale_Price     736936.769025  960408.078866

# %%
#making new column
data['grade_mean']=0

#for every grade fill it's mean in a new column
for i in grades_mean.columns:
    data['grade_mean'][data['Overall Grade']==i] = grades_mean[i][0]
    
data['grade_mean'].head()
# Out:
# 0    402239.619779
# 1    402239.619779
# 2    301882.014720
# 3    402239.619779
# 4    537584.082097
# Name: grade_mean, dtype: float64

# %%
gradewise_list=[]
for i in range(1,11):
    k=data["Sale_Price"][data["Overall Grade"]==i]
    gradewise_list.append(k)

# %%
Classwise_list=[]
for i in range(1,11):
    k=data["Sale_Price"][data["Overall Grade"]==i]
    Classwise_list.append(k)

# %%
plt.figure( dpi = 120, figsize = (15,9) )

#### Plotting "Sale_Price" gradewise ####
# z variable is for x-axis
z = 0
for i in range(1,11):
  # defining x-axis using z
  points = [k for k in range(z, z + len(gradewise_list[i-1]))]
  # plotting
  plt.scatter( points, # x-axis
              np.sort(gradewise_list[i-1], axis = 0) , # y-axis
              label = ('houses with overall grade', i), s = 4 )            
  z = max(points) + 1 # updating z for next plot

#### plotting Overall Mean ####
plt.scatter([q for q in range(0, z)],
         data['mean_sales'],
         color = 'red',
         label = 'Overall Mean',
         s = 8)

plt.xlabel('Fitted points (Ascending)')
plt.ylabel("Sale Price")
plt.title('Overall Mean')
plt.legend( loc = 4)

# %%
mean_difference = data['mean_sales'] - data['Sale_Price']
grade_mean_difference = data['grade_mean'] - data['Sale_Price']

# %%
k = range(0, len(data))
l = [0 for i in range(len(data))]

plt.figure( figsize = (15,6), dpi =100)

plt.subplot(1,2,1)
plt.scatter( k , mean_difference, color = 'violet', label = 'Residuals', s = 2 )
plt.plot( k , l, color = 'green', label = 'mean Regression', linewidth = 3)
plt.xlabel('Fitted points')
plt.ylabel("Residuals")
plt.title('Residuals with respect to Overall Mean')

plt.subplot(1,2,2)
plt.scatter( k , grade_mean_difference, color = 'skyblue', label = 'Residuals', s = 2 )
plt.plot( k , l, color = 'green', label = 'mean Regression', linewidth = 3)
plt.xlabel('Fitted points')
plt.ylabel("Residuals")
plt.legend()
plt.title("Residuals with respect to Overall Housing Grade")

plt.legend()

# %%
mean_error = sum(mean_difference)/len(data)
print(round(mean_error, 7))
# Out:
# 0.0

# %%
Y = data["Sale_Price"]
Y_hat1 = data["mean_sales"]
Y_hat2 = data['grade_mean']
n = len(data)

len(Y), len(Y_hat1), len(Y_hat2), n
# Out:
# (21609, 21609, 21609, 21609)

# %%
mean_absolute_error1 = sum(abs(Y_hat1 - Y))/n
mean_absolute_error1
# Out:
# 199168.78146839526

# %%
mean_absolute_error2 = sum(abs(Y_hat2 - Y))/n
mean_absolute_error2
# Out:
# 137081.70298203363

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error_2 = mean_absolute_error(Y_hat2, Y)
mean_absolute_error_2
# Out:
# 137081.7029820291

# %%
from sklearn.metrics import mean_squared_error
mse1 = mean_squared_error( Y_hat1, Y)
mse2 = mean_squared_error(Y_hat2, Y)
mse1, mse2
# Out:
# (62528116847.799576, 30804835720.342426)

# %%
from sklearn.metrics import mean_squared_error
rmse1 = mean_squared_error( Y_hat1, Y)**0.5
rmse2 = mean_squared_error(Y_hat2, Y)**0.5
rmse1, rmse2
# Out:
# (250056.2273725643, 175513.06424406826)

# %%
Y = data["Sale_Price"]
Y_bar = data["mean_sales"]
Y_hat = data['grade_mean']
n = len(data)

len(Y), len(Y_bar), len(Y_hat), n
# Out:
# (21609, 21609, 21609, 21609)

# %%
mse_mean = mean_squared_error( Y_bar, Y)
mse_mean
# Out:
# 62528116847.799576

# %%
mse_model = mean_squared_error( Y_hat, Y)
mse_model
# Out:
# 30804835720.342426

# %%
R2 = 1 - (mse_model / mse_mean)
R2
# Out:
# 0.5073442592981836

# %%
from sklearn.metrics import r2_score
score = r2_score(Y, Y_hat)
score
# Out:
# 0.5073442592981836

# %% [markdown]
# # Linear regression :-
#                                  It models the linear relationship between the dependent & independent variable

# %% [markdown]
# Extracting the first 30 rows of sale_price & flat_area from Transformed_Housing_Data2.csv file
#
# Arrange sale_price and flat_area in sample_data

# %%
sale_price = data["Sale_Price"].head(30)
flat_area = data['Flat Area (in Sqft)'].head(30)
sample_data = pd.DataFrame({ 'sale_price': sale_price,
                              'flat_area': flat_area})
sample_data
# Out:
#     sale_price  flat_area
# 0     221900.0     1180.0
# 1     538000.0     2570.0
# 2     180000.0      770.0
# 3     604000.0     1960.0
# 4     510000.0     1680.0
# 5    1129575.0     5420.0
# 6     257500.0     1715.0
# 7     291850.0     1060.0
# 8     229500.0     1780.0
# 9     323000.0     1890.0
# 10    662500.0     3560.0
# 11    468000.0     1160.0
# 12    310000.0     1430.0
# 13    400000.0     1370.0
# 14    530000.0     1810.0
# 15    650000.0     2950.0
# 16    395000.0     1890.0
# 17    485000.0     1600.0
# 18    189000.0     1200.0
# 19    230000.0     1250.0
# 20    385000.0     1620.0
# 21   1129575.0     3050.0
# 22    285000.0     2270.0
# 23    252700.0     1070.0
# 24    329000.0     2450.0
# 25    233000.0     1710.0
# 26    937000.0     2450.0
# 27    667000.0     1400.0
# 28    438000.0     1520.0
# 29    719000.0     2570.0

# %% [markdown]
# Plotting the scatter plot graph based on variation of Sale Price with Flat Area using matplotlib library

# %%
plt.figure( dpi = 150)
plt.scatter(sample_data.flat_area, sample_data.sale_price, color = 'red', label = 'sale_price')
plt.xlabel('Flat_Area')
plt.ylabel('Sale_Price')
plt.title("Sale_Price/Flat_Area")
plt.legend()
plt.show()

# %% [markdown]
# From the above graph we can see that Sale Price increases with the increase in flat area.

# %%
#Suppose,A person wants to sell all house so for prediction if he/she uses the mean prediction model
#Graph of variation of Sale Price with flat area using mean regression model :- 
sample_data['mean_sale_price'] = sample_data.sale_price.mean()


plt.figure( dpi = 150)
plt.scatter(sample_data.flat_area, sample_data.sale_price, color = 'red')
plt.plot(sample_data.flat_area, sample_data.mean_sale_price, color = "yellow", label = 'Mean Sale Price')
plt.xlabel('Flat_Area')
plt.ylabel('Sale_Price')
plt.title("Sale_Price/Flat_Area")
plt.legend()
plt.show()

# %% [markdown]
# From the above graph ,we can see that increase in Sale Price with Flat Area is straight line of the average of sale price ,
# which is actually not the right prediction.

# %% [markdown]
# Equation of straight line:-
#
#                      y=mx+c
# Where,
#
# y=Independent variable
#
# x=Dependent variable
#
# m=slope of the line
#
# c=intercept(The point where the line cuts the y-axis)

# %% [markdown]
# # Manual method of finding the optimised value of slope and intercept using Cost Function Curve

# %%
# Variation of Sale Price with Flat area using linear regression model

c = 0
m = 0

# line is list , where the computed value of y are stored
line = []

for i in range(len(sample_data)):
    line.append(sample_data.flat_area[i] * m + c)

plt.figure(dpi = 130)
plt.scatter(sample_data.flat_area, sample_data.sale_price)
plt.plot(sample_data.flat_area, line, label = 'm = 0.0; c = 0')
plt.xlabel('Flat_Area')
plt.ylabel('Sale_Price')
plt.legend()

#Mean Square Error function
#Calculating error i.e with MSE w.r.t line
MSE = mse(sample_data.sale_price, line)
plt.title("Slope "+str(m)+" with MSE "+ str(MSE))
# Out:
# Text(0.5, 1.0, 'Slope 0 with MSE 281372081125.0')

# %% [markdown]
# From the above graph, we can see that the line models the data very poorly and MSE value is too large.

# %%
#In the above graph as the line models the data poorly 
#Therefore we will increase slope from 0 to 50

c = 0
m = 50

line = []

for i in range(len(sample_data)):
    line.append(sample_data.flat_area[i] * m + c)

plt.figure(dpi = 130)
plt.scatter(sample_data.flat_area, sample_data.sale_price)
plt.plot(sample_data.flat_area, line, label = 'm = 50; c = 0')
plt.xlabel('Flat_Area')
plt.ylabel('Sale_Price')
plt.legend()
MSE = mse(sample_data.sale_price, line)
plt.title("Slope "+str(m)+" with MSE "+ str(MSE))
# Out:
# Text(0.5, 1.0, 'Slope 50 with MSE 184728400708.33334')

# %% [markdown]
# We can see the line fits the data good enough as compared to previous graph even the MSE value is also low than the previous graph, but still this line also models the data very poorly.

# %%
def slope_Error( slope, intercept ,  sample_data):
    sale = []
    for i in range(len(sample_data.flat_area)):
        tmp = sample_data.flat_area[i] * slope + intercept
        sale.append(tmp)
    MSE = mse(sample_data.sale_price, sale)
    return MSE

# %%
slope = [i/10 for i in range(0,5000)]
Cost = []
for i in slope:
    cost = slope_Error( slope = i, intercept = 0, sample_data = sample_data)
    Cost.append(cost)

# %%
# Arranging in DataFrame
Cost_table = pd.DataFrame({
    'slope' : slope,
    'Cost' : Cost
})
Cost_table.tail()
# Out:
#       slope          Cost
# 4995  499.5  3.526038e+11
# 4996  499.6  3.528488e+11
# 4997  499.7  3.530938e+11
# 4998  499.8  3.533389e+11
# 4999  499.9  3.535842e+11

# %%
# plotting the cost values corresponding to every value of Beta
plt.plot(Cost_table.slope, Cost_table.Cost, label = 'Cost Function Curve')
plt.xlabel('Value of slope')
plt.ylabel('Cost')
plt.legend()

# %%
new_slope = Cost_table['slope'][Cost_table['Cost'] == Cost_table['Cost'].min()].values
new_slope[0]
# Out:
# 234.3

# %%
def intercept_Error( slope, intercept ,  sample_data):
    sale = []
    for i in range(len(sample_data.flat_area)):
        tmp = sample_data.flat_area[i] * slope + intercept
        sale.append(tmp)
    MSE = mse(sample_data.sale_price, sale)
    return MSE

# %%
intercept = [i for i in range(5000,50000)]
Cost = []
for i in intercept:
    cost = intercept_Error( slope = 234, intercept = i, sample_data = sample_data)
    Cost.append(cost)

# %%
# Arranging in DataFrame
Cost_table = pd.DataFrame({
    'intercept' : intercept,
    'Cost' : Cost
})
Cost_table.head()
# Out:
#    intercept          Cost
# 0       5000  2.779911e+10
# 1       5001  2.779909e+10
# 2       5002  2.779908e+10
# 3       5003  2.779907e+10
# 4       5004  2.779906e+10

# %%
# plotting the cost values corresponding to every value of Beta
plt.plot(Cost_table.intercept, Cost_table.Cost, label = 'Cost Function Curve')
plt.xlabel('Value of intercept')
plt.ylabel('Cost')
plt.legend()

# %%
new_intercept = Cost_table['intercept'][Cost_table['Cost'] == Cost_table['Cost'].min()].values
new_intercept[0]
# Out:
# 10834

# %%
slope = [i/10 for i in range(0,5000)]
Cost = []
for i in slope:
    cost = slope_Error( slope = i, intercept = 10834, sample_data = sample_data)
    Cost.append(cost)

# %%
# Arranging in DataFrame
Cost_table = pd.DataFrame({
    'slope' : slope,
    'Cost' : Cost
})
Cost_table.tail()
# Out:
#       slope          Cost
# 4995  499.5  3.636767e+11
# 4996  499.6  3.639259e+11
# 4997  499.7  3.641751e+11
# 4998  499.8  3.644245e+11
# 4999  499.9  3.646739e+11

# %%
# plotting the cost values corresponding to every value of Beta
plt.plot(Cost_table.slope, Cost_table.Cost, label = 'Cost Function Curve')
plt.xlabel('Value of slope')
plt.ylabel('Cost')
plt.legend()

# %%
new_slope = Cost_table['slope'][Cost_table['Cost'] == Cost_table['Cost'].min()].values
new_slope[0]
# Out:
# 229.7

# %%
intercept = [i for i in range(5000,50000)]
Cost = []
for i in intercept:
    cost = intercept_Error( slope = 229.7, intercept = i, sample_data = sample_data)
    Cost.append(cost)

# %%
# Arranging in DataFrame
Cost_table = pd.DataFrame({
    'intercept' : intercept,
    'Cost' : Cost
})
Cost_table.head()
# Out:
#    intercept          Cost
# 0       5000  2.781305e+10
# 1       5001  2.781302e+10
# 2       5002  2.781299e+10
# 3       5003  2.781296e+10
# 4       5004  2.781293e+10

# %%
# plotting the cost values corresponding to every value of Beta
plt.plot(Cost_table.intercept, Cost_table.Cost, label = 'Cost Function Curve')
plt.xlabel('Value of intercept')
plt.ylabel('Cost')
plt.legend()

# %%
new_intercept = Cost_table['intercept'][Cost_table['Cost'] == Cost_table['Cost'].min()].values
new_intercept[0]
# Out:
# 19199

# %% [markdown]
# # Gradient Descent :-
#                                  It is an optimization algorithm that works iteratively & ends to find the minimum value of convex function with respect to set of parameters.

# %%
sale_price = data["Sale_Price"].head(30)
flat_area = data['Flat Area (in Sqft)'].head(30)
sample_data = pd.DataFrame({ 'sale_price': sale_price,
                              'flat_area': flat_area})
sample_data.head()
# Out:
#    sale_price  flat_area
# 0    221900.0     1180.0
# 1    538000.0     2570.0
# 2    180000.0      770.0
# 3    604000.0     1960.0
# 4    510000.0     1680.0

# %% [markdown]
# Random initialisation of m from small value & taking the value of intercept from mean regression model

# %%
def param_init(Y):
  '''
  Y = target variable
  returns initialized values of m and c
  '''
  m = 0.1
  c = Y.mean()
  return m, c

# %% [markdown]
# Generating predictions

# %%
def generate_predictions(m, c, X):
  '''
  X = independent variable
  returns prediction generated by line with parameters m, c
  '''
  prediction = []
  for x in X:
    pred = (m * x) + c
    prediction.append(pred)
  return prediction

# %% [markdown]
# Cost is the MSE=Actual value-Predicted value

# %%
def compute_cost(prediction, Y):
  '''
  returns the mean_squared_error between prediction and Y
  '''
  cost = np.sum(((prediction - Y)**2)/len(Y))
  return cost

# %% [markdown]
# Update Parameters :-
#     1.Calculate Gradeient

# %%
def gradients(prediction, Y, X):
  '''
  Returns Gradients corresponding to m and c
  '''
  n = len(Y)
  Gm = 2/n * np.sum((prediction - Y) * X)
  Gc = 2/n * np.sum((prediction - Y))
  return Gm, Gc

# %% [markdown]
# 2. Update the gradient

# %%
def param_update(m_old , c_old , Gm_old, Gc_old, alpha):
  '''
  Update and return the new values of m and c
  '''
  m_new = m_old - alpha * Gm_old
  c_new = c_old - alpha * Gc_old
  return m_new, c_new

# %%
def result(m, c, X, Y, cost, predictions, i):
  '''
  Print and plot the final result obtained from gradient descent
  '''
  ##If the Gradient Descent converged to the optimum value before max_iter
  if i < max_iter - 1 :
    print("***** Gradient Descent has converged at iteration {} *****".format(i))
  else:
    print("***** Result after", max_iter,'iterations is: *****')
  
  ## plotting the final result
  plt.figure(figsize = (14,7), dpi = 120)
  plt.scatter(X, Y, color = 'yellow', label = 'data points')
  label = 'final regression line: m = {}; c = {}'.format(str(m), str(c))
  plt.plot(X, predictions, color = 'green', label = label)
  plt.xlabel('flat_area')
  plt.ylabel('sale_price')
  plt.title('final regression line')
  plt.legend()

# %%
## defining and reshaping the dataset
sale_price = sample_data['sale_price'].values.reshape(-1,1)
flat_area = sample_data['flat_area'].values.reshape(-1,1)

## declaring parameters
max_iter = 1000
cost_old = 0
alpha = 0.01

## Step 1: inititialising the values of m, c
m , c = param_init(sale_price)

## Gradient Descent in action
for i in range(0 , max_iter):
  
  ## Step 2: genrating predictions
  predictions = generate_predictions(m , c , flat_area)

  ## Step 3: calculating cost
  cost_new = compute_cost(predictions , sale_price)

  ## checking if GD converged
  if abs(cost_new - cost_old) < 10**(-7):
    break
  
  ## calculating gradients
  Gm, Gc = gradients(predictions, sale_price,
                     flat_area)
  
  ## Step 4: updating parameters m and c
  m, c = param_update(m, c, Gm, Gc, alpha)

  ## display result after every 20 iterations
  if i%20 == 0:
    print('After Iteration', i,': m =', m, '; c =', c,'; Cost =', cost_new)

  ##updating cost_old
  cost_old = cost_new

## final results
result(m , c, flat_area, sale_price,
       cost_new, predictions, i)
# Out:
# After Iteration 0 : m = 3499072.307222223 ; c = 465999.44299999997 ; Cost = 64177937552.075005
# After Iteration 20 : m = 7.115927055971628e+105 ; c = 2.997778392048355e+102 ; Cost = 2.7417231010181384e+208
# After Iteration 40 : m = 1.447154337383132e+205 ; c = 6.096532424296826e+201 ; Cost = inf
# After Iteration 60 : m = 2.9430538842431367e+304 ; c = 1.2398417341018387e+301 ; Cost = inf
# After Iteration 80 : m = nan ; c = nan ; Cost = nan
# After Iteration 100 : m = nan ; c = nan ; Cost = nan
# After Iteration 120 : m = nan ; c = nan ; Cost = nan
# After Iteration 140 : m = nan ; c = nan ; Cost = nan
# After Iteration 160 : m = nan ; c = nan ; Cost = nan
# After Iteration 180 : m = nan ; c = nan ; Cost = nan
# After Iteration 200 : m = nan ; c = nan ; Cost = nan
# After Iteration 220 : m = nan ; c = nan ; Cost = nan
# After Iteration 240 : m = nan ; c = nan ; Cost = nan
# After Iteration 260 : m = nan ; c = nan ; Cost = nan
# After Iteration 280 : m = nan ; c = nan ; Cost = nan
# ...

# %%
## scaling the dataset using the standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
sale_price = scaler.fit_transform(sample_data['sale_price'].values.reshape(-1,1))
flat_area = scaler.fit_transform(sample_data['flat_area'].values.reshape(-1,1))

## declaring parameters
max_iter = 1000
cost_old = 0
alpha = 0.01

## Step 1: inititialising the values of m, c
m , c = param_init(sale_price)

## Gradient Descent in action
for i in range(0 , max_iter):
  
  ## Step 2: genrating predictions
  predictions = generate_predictions(m , c , flat_area)

  ## Step 3: calculating cost
  cost_new = compute_cost(predictions , sale_price)

  ## checking if GD converged
  if abs(cost_new - cost_old) < 10**(-7):
    break
  
  ## calculating gradients
  Gm, Gc = gradients(predictions, sale_price,
                     flat_area)
  
  ## Step 4: updating parameters m and c
  m, c = param_update(m, c, Gm, Gc, alpha)

  ## display result after every 20 iterations
  if i%20 == 0:
    print('After Iteration', i,': m =', m, '; c =', c,'; Cost =', cost_new)

  ##updating cost_old
  cost_old = cost_new

## final results
result(m , c, flat_area, sale_price,
       cost_new, predictions, i)
# Out:
# After Iteration 0 : m = 0.11316346413633305 ; c = 1.1849780416165836e-16 ; Cost = 0.85836535863667
# After Iteration 20 : m = 0.3275595607435688 ; c = 1.240489192847842e-16 ; Cost = 0.6182472245590185
# After Iteration 40 : m = 0.4706921039517346 ; c = 1.3248661427193537e-16 ; Cost = 0.5112264752046607
# After Iteration 60 : m = 0.5662485308150865 ; c = 1.415904430738617e-16 ; Cost = 0.46352728398628984
# After Iteration 80 : m = 0.6300427631414932 ; c = 1.4951003398285442e-16 ; Cost = 0.4422677351921283
# After Iteration 100 : m = 0.6726323011945988 ; c = 1.611303683072644e-16 ; Cost = 0.4327923457067555
# After Iteration 120 : m = 0.7010654163122192 ; c = 1.666074685620818e-16 ; Cost = 0.42856916078553225
# After Iteration 140 : m = 0.7200475906265729 ; c = 1.6660746856208182e-16 ; Cost = 0.4266868855601835
# After Iteration 160 : m = 0.7327202415200801 ; c = 1.669405354694694e-16 ; Cost = 0.42584795473189874
# ...

# %% [markdown]
# # Implementing Linear regression

# %% [markdown]
# 1.Scaling the dataset
#
#
# 2.Checking Multicollinearity and removing it
#
#
# 3.Creating test and training partitions
#
#
# 4.Implementing the Linear Regression model
#
#
# 5.Generating predictions over the test set
#
#
# 6.Evaluating the model
#
#
# 7.Preparing the Residual plot.
#
#
# 8.Checking the Assumptions of Linear Regression.
#
#
# 9.Visualising the Coefficient plot

# %% [markdown]
# Scaling the dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
Y = data['Sale_Price']
X = scaler.fit_transform(data.drop(columns = ['Sale_Price']))
X = pd.DataFrame(data = X, columns = data.drop(columns = ['Sale_Price']).columns)
X.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0       -0.398724        -1.447526            -0.979905           -0.228291
# 1       -0.398724         0.175684             0.533718           -0.189858
# 2       -1.474115        -1.447526            -1.426369           -0.123276
# 3        0.676667         1.149611            -0.130534           -0.243983
# 4       -0.398724        -0.148958            -0.435436           -0.169628
#
#    No of Floors  No of Times Visited  Overall Grade  \
# 0     -0.915389             -0.30579      -0.563993
# 1      0.936817             -0.30579      -0.563993
# 2     -0.915389             -0.30579      -1.468566
# 3     -0.915389             -0.30579      -0.563993
# 4     -0.915389             -0.30579       0.340581
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                  -0.734722                -0.658697
# ...

# %% [markdown]
# Multicollinearity is the corelation among the independent variable and
# x.corr() function gives every possible pair of variables in dataset

# %% [markdown]
# Checking and Removing Multicollinearity

# %%
X.corr()
# Out:
#                                            No of Bedrooms  No of Bathrooms  \
# No of Bedrooms                                   1.000000         0.515813
# No of Bathrooms                                  0.515813         1.000000
# Flat Area (in Sqft)                              0.576628         0.754568
# Lot Area (in Sqft)                               0.031692         0.087732
# No of Floors                                     0.175536         0.500776
# No of Times Visited                              0.079575         0.187791
# Overall Grade                                    0.349223         0.635638
# Area of the House from Basement (in Sqft)        0.477549         0.685088
# Basement Area (in Sqft)                          0.303294         0.283798
# Age of House (in Years)                         -0.154113        -0.505954
# Latitude                                        -0.008708         0.024570
# ...

# %% [markdown]
# There are total 900 corelation  in this output.It is very tedious to work with 900 values
# & to find the correlation above 0.5 manually.

# %%
## pair of independent variables with correlation greater than 0.5
k = X.corr()
z = [[str(i),str(j)] for i in k.columns for j in k.columns if (k.loc[i,j] >abs(0.5))&(i!=j)]
z, len(z)
# Out:
# ([['No of Bedrooms', 'No of Bathrooms'],
#   ['No of Bedrooms', 'Flat Area (in Sqft)'],
#   ['No of Bathrooms', 'No of Bedrooms'],
#   ['No of Bathrooms', 'Flat Area (in Sqft)'],
#   ['No of Bathrooms', 'No of Floors'],
#   ['No of Bathrooms', 'Overall Grade'],
#   ['No of Bathrooms', 'Area of the House from Basement (in Sqft)'],
#   ['No of Bathrooms', 'Living Area after Renovation (in Sqft)'],
#   ['No of Bathrooms', 'grade_mean'],
#   ['Flat Area (in Sqft)', 'No of Bedrooms'],
#   ['Flat Area (in Sqft)', 'No of Bathrooms'],
#   ['Flat Area (in Sqft)', 'Overall Grade'],
#   ['Flat Area (in Sqft)', 'Area of the House from Basement (in Sqft)'],
#   ['Flat Area (in Sqft)', 'Living Area after Renovation (in Sqft)'],
#   ['Flat Area (in Sqft)', 'grade_mean'],
#   ['Lot Area (in Sqft)', 'Lot Area after Renovation (in Sqft)'],
#   ['No of Floors', 'No of Bathrooms'],
#   ['No of Floors', 'Area of the House from Basement (in Sqft)'],
#   ['Overall Grade', 'No of Bathrooms'],
# ...

# %% [markdown]
# Treating multicollinearity using  VIF i.e by calculating variance inflation factor:-

# %%
# Importing Variance_inflation_Factor funtion from the Statsmodels
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_data = X

## Calculating VIF for every column
VIF = pd.Series([variance_inflation_factor(vif_data.values, i) for i in range(vif_data.shape[1])], index = vif_data.columns)
VIF
# Out:
# No of Bedrooms                                  1.700187
# No of Bathrooms                                 3.375782
# Flat Area (in Sqft)                          1482.038878
# Lot Area (in Sqft)                              2.108170
# No of Floors                                    2.129338
# No of Times Visited                             1.438889
# Overall Grade                                  13.055456
# Area of the House from Basement (in Sqft)    1205.601277
# Basement Area (in Sqft)                       345.481515
# Age of House (in Years)                         2.634330
# Latitude                                        2.471466
# Longitude                                       1.675510
# Living Area after Renovation (in Sqft)          3.085535
# Lot Area after Renovation (in Sqft)             2.144405
# Years Since Renovation                          2.788693
# Condition_of_the_House_Excellent               53.694364
# ...

# %% [markdown]
# VIF of flat area is maximum

# %%
VIF[VIF == VIF.max()].index[0]
# Out:
# 'Flat Area (in Sqft)'

# %% [markdown]
# If VIF>5 then remove them as multicollinearity is present in them and drop the column containing variables with multicollinearity.
# If VIF<5 then return the data as multicollinerity is not present

# %%
def MC_remover(data):
  vif = pd.Series([variance_inflation_factor(data.values, i) for i in range(data.shape[1])], index = data.columns)
  if vif.max() > 5:
    print(vif[vif == vif.max()].index[0],'has been removed')
    data = data.drop(columns = [vif[vif == vif.max()].index[0]])
    return data
  else:
    print('No Multicollinearity present anymore')
    return data

# %% [markdown]
# Those variables containing multicollinearity are not removed as their VIF value is reduced to less than 5:-

# %%
for i in range(7):
  vif_data = MC_remover(vif_data)

vif_data.head()
# Out:
# Flat Area (in Sqft) has been removed
# Condition_of_the_House_Fair has been removed
# grade_mean has been removed
# No Multicollinearity present anymore
# No Multicollinearity present anymore
# No Multicollinearity present anymore
# No Multicollinearity present anymore
#    No of Bedrooms  No of Bathrooms  Lot Area (in Sqft)  No of Floors  \
# 0       -0.398724        -1.447526           -0.228291     -0.915389
# 1       -0.398724         0.175684           -0.189858      0.936817
# 2       -1.474115        -1.447526           -0.123276     -0.915389
# 3        0.676667         1.149611           -0.243983     -0.915389
# 4       -0.398724        -0.148958           -0.169628     -0.915389
#
#    No of Times Visited  Overall Grade  \
# 0             -0.30579      -0.563993
# 1             -0.30579      -0.563993
# 2             -0.30579      -1.468566
# 3             -0.30579      -0.563993
# 4             -0.30579       0.340581
#
# ...

# %% [markdown]
# Therefore no multicollinearity is present anymore.

# %% [markdown]
# Calculating VIF of remaining column:-

# %%
# Calculating VIF for remaining columns
VIF = pd.Series([variance_inflation_factor(vif_data.values, i) for i in range(vif_data.shape[1])], index = vif_data.columns)
VIF, len(vif_data.columns)
# Out:
# (No of Bedrooms                               1.638990
#  No of Bathrooms                              3.373805
#  Lot Area (in Sqft)                           2.107495
#  No of Floors                                 2.127703
#  No of Times Visited                          1.432363
#  Overall Grade                                2.956967
#  Area of the House from Basement (in Sqft)    4.580042
#  Basement Area (in Sqft)                      1.974981
#  Age of House (in Years)                      2.626504
#  Latitude                                     2.471343
#  Longitude                                    1.672667
#  Living Area after Renovation (in Sqft)       3.063886
#  Lot Area after Renovation (in Sqft)          2.144068
#  Years Since Renovation                       2.788064
#  Condition_of_the_House_Excellent             1.206487
#  Condition_of_the_House_Good                  1.251488
#  Condition_of_the_House_Okay                  1.025386
# ...

# %% [markdown]
# None of the variable has VIF value above 5.Therefore the problem of multicollinearity has been solved.

# %% [markdown]
# Train/Test set

# %%
X = vif_data
Y = data['Sale_Price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 101)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((15126, 29), (6483, 29), (15126,), (6483,))

# %% [markdown]
# Linear regression

# %% [markdown]
# SKlearn library allows us to implement linear regression model without writing our own code for gradient descent:-

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(normalize = True)
# lr.fit is the function that implements the gradient descent & compute procedure over the training data
# Gradient Descent finds the best set of parameters to model the data
lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
lr.coef_
# Out:
# array([ -3928.66247639,  12028.44560689,  14967.00497585,   2697.55278605,
#         27220.31313417,  59965.44665815,  80697.80906997,  27729.56715434,
#         27873.90231343,  21397.40341959, -23854.32640243,  17943.26729788,
#         -2896.98542901, -10179.085198  ,  14239.3533334 ,   5095.97603571,
#         -2296.64888137,  14594.33847962,  10761.77007875,  12165.83372082,
#         33842.29544383,  63269.82875283,  81086.08553213,  50718.63947886,
#         73274.09568028,  40153.03595158,  67405.70271285,  22113.74944051,
#             0.        ])

# %% [markdown]
# Generating predictions over test set:-

# %%
#x_test is an independent variable set
predictions = lr.predict(x_test)

# %%
lr.score(x_test, y_test)
# Out:
# 0.8461987715586199

# %% [markdown]
# This is an score which shows that it is linear regression model.

# %% [markdown]
# VARIFYING THE ASSUMPTION OF LINEAR REGRESSION:-

# %% [markdown]
# 1. Residuals Plot

# %%
#Difference between the predicted & actual values known as residuals
residuals = predictions - y_test

residual_table = pd.DataFrame({'residuals':residuals,
                    'predictions':predictions})
residual_table = residual_table.sort_values( by = 'predictions')

# %%
z = [i for i in range(int(residual_table['predictions'].max()))]
k = [0 for i in range(int(residual_table['predictions'].max()))]

# %%
plt.figure(dpi = 130, figsize = (17,7))

plt.scatter( residual_table['predictions'], residual_table['residuals'], color = 'red', s = 2)
plt.plot(z, k, color = 'green', linewidth = 3, label = 'regression line')
plt.ylim(-800000, 800000)
plt.xlabel('fitted points (ordered by predictions)')
plt.ylabel('residuals')
plt.title('residual plot')
plt.legend()
plt.show()

# %% [markdown]
# 2. Distribution of errors

# %%
plt.figure(dpi = 100, figsize = (10,7))
plt.hist(residual_table['residuals'], color = 'red', bins = 200)
plt.xlabel('residuals')
plt.ylabel('frequency')
plt.title('distribution of residuals')
plt.show()

# %%
coefficients_table = pd.DataFrame({'column': x_train.columns,
                                  'coefficients': lr.coef_})
coefficient_table = coefficients_table.sort_values(by = 'coefficients')

# %%
plt.figure(figsize=(8, 6), dpi=100)
x = coefficient_table['column']
y = coefficient_table['coefficients']
plt.barh( x, y)
plt.xlabel( "Coefficients")
plt.ylabel('Variables')
plt.title('Normalized Coefficient plot')
plt.show()
